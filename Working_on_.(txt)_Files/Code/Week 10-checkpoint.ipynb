# %% [markdown]
# # Week - 10 Assignment

# %%
#Importing required libraries
import zipfile
import glob 
from zipfile import ZipFile

# %%
# Reading the zip file using zipfile.ZipFile class
zip = zipfile.ZipFile('week_10_txt_and_docx.zip')

# %%
# Extracting all the file from the zip file into Week 10 folder
with ZipFile("week_10_txt_and_docx.zip", 'r') as zip: 
    print('Extracting all the files now...') 
    zip.extractall("Week 10")
# Out:
# Extracting all the files now...

# %%
# Printing all the files with .txt and .docx format using golb.glob function
glob.glob("C:/Users/gouth/DATA 601/week_10_txt_and_docx/*")
# Out:
# ['C:/Users/gouth/DATA 601/week_10_txt_and_docx\\52256-0.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\53031-0.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\58108-0.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\blind_text.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\dr_yawn.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\how_rubber_goods_are_made.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\most_boring_ever.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\most_boring_part2.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\pg12814.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\pg14895.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\pg43994.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\random_text.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\smiley_the_bunny.txt',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\week_10_document1.docx',
#  'C:/Users/gouth/DATA 601/week_10_txt_and_docx\\week_10_document2.docx']

# %%
# Taking all the files with .txt extension into list1
list1=glob.glob("Week 10/*.txt")

# %%
# Taking all the files with .docx extension into list2
list2=glob.glob("Week 10/*.docx")

# %%
# A new list named list_final consisting of all the .txt and .docx files
list_final=list1+list2

# %% [markdown]
# Function for reading a text file.

# %%
def readtxtFile(file):
    # Opening the text file in 8-bit Unicode Transformation Format
    file1=open(file,"r",encoding="utf8")
    # Reading the text in the file as a string type
    string1 = file1.read()
    return string1

# %% [markdown]
# Functon to remove the punctuation marks

# %%
def remove_punctuation(string1):
    # Taking all the punctuation marks as a string
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    # Creating a new empty string
    new_string=''
    for char in string1:
        # For every character in the string passed, if the character is not a punctuation
        if char not in punctuations:
            # Add that charecter to the new_string
            new_string = new_string + char
    return new_string

# %% [markdown]
# Function to remove the URLs from a string

# %%
def removeURLs(string1):
    return re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', string1)
# Citation 
# https://stackoverflow.com/questions/11331982/how-to-remove-any-url-within-a-string-in-python

# %%
#import nltk
#nltk.download()

# %%
# Importing stopwords from natural language tool kit
from nltk.corpus import stopwords
# Getting english stopwords
stopwords = set(stopwords.words('english'))

# %%
print(stopwords)
# Out:
# {'as', 'hers', "aren't", "doesn't", 'on', 'i', 'over', 'shouldn', 'some', "you've", "you're", "that'll", 'isn', 'just', 'which', 'myself', 'been', 'your', 'what', 'do', 'most', 'or', 'below', 'to', 'our', 's', 'from', 'won', 'very', 'such', "shan't", 'if', 'of', 'before', 'after', 'against', "haven't", 'them', 'out', 'between', "she's", 'll', 'into', 'during', 'there', 'was', "mustn't", 'm', 'down', 'other', 'more', 'haven', 'his', 'each', "hadn't", 'an', 'ours', 'wouldn', 'herself', 'theirs', 'doesn', 'does', 'yourselves', 'me', 'through', 'who', 'above', 'having', 'this', 'did', 'but', 'why', 'himself', 'can', "isn't", 'the', 'up', 'yours', 'have', 'now', 'being', "should've", 'here', 'too', 'has', 'mustn', 'we', 'be', 'no', 'while', 'off', 'nor', "couldn't", 'her', 'whom', 'under', 'again', 'both', "hasn't", 'are', 'where', 'my', 'those', 'by', "you'd", 'all', 'don', 'doing', 'needn', "wasn't", 'once', 'were', "you'll", 'they', 'it', 'themselves', "didn't", 'him', 're', 'than', 'couldn', 've', 'you', 'had', 'few', 'y', 'he', 'am', "don't", 'only', 'ain', 'ma', 'their', 'and', 'because', 'is', "mightn't", 'd', 'these', 'with', 't', 'yourself', 'didn', 'until', 'she', 'how', 'will', 'same', "weren't", 'in', 'not', 'for', "won't", 'its', 'ourselves', 'shan', 'weren', "it's", 'wasn', 'that', 'hadn', 'then', 'own', 'hasn', 'at', 'about', "shouldn't", "wouldn't", 'further', 'a', 'mightn', "needn't", 'when', 'itself', 'should', 'o', 'aren', 'so', 'any'}

# %% [markdown]
# Function to remove the stopwords

# %%
def removeStopwords(a):    
    new_list=[]
    # For the elements in the list passed, if it is not in stopwords append it to new list.
    for i in a:
        if i not in stopwords:
            new_list.append(i)
    return new_list

# %% [markdown]
# Function to convert string to list

# %%
import re 
def stringToList(stri):
    # reading the string and writing each word into a list 
    new_list = re.findall(r'\w+', stri) 
    return new_list

# %% [markdown]
# Function to read the text in .docx file into a list and return it.

# %%
import docx
def readDocxfile(filename):
    # Reading the file using docx.Document function
    doc = docx.Document(filename)
    fullText = []
    # Reading the paragraphs in the file ordrly and appending the text in those paragraphs to a list. 
    for para in doc.paragraphs:
        fullText.append(para.text)
    return fullText

# %% [markdown]
# Function to convert list to string

# %%
def listToString(list1):
    str1 = ""    
    for ele in list1:  
        str1 += ele   
    return str1

# %% [markdown]
# Function to return the unique words in a list

# %%
def uniqueWordsInlist(list1):
    list2=[]
    for i in list1:
        if i not in list2:
            list2.append(i)
    return list2

# %%
pip install python-docx
# Out:
# Requirement already satisfied: python-docx in c:\programdata\anaconda3\lib\site-packages (0.8.10)
# Requirement already satisfied: lxml>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from python-docx) (4.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
str1 = ""
def remove(a):
    #str1= " " 
    # Using a string str1 defined outside the function so that when the function is called recursively it doesn't start with an empty string.
    global str1
    # Adding name of the file to the string
    str1 += '"' +a+ '"'
    str1 += " : "
    # If the file passed to the function is a text file.
    if a.endswith('.txt'):
        #calling readtxtFile function to read the text file as a string
        b=readtxtFile(a)
        # Calling function to remove URLs from string
        c=removeURLs(b)
        # Calling remove_punctution function to remove punctuations from the string
        d=remove_punctuation(c)
        # Converting all the words into lower case letters
        e=d.lower()
        # Converting the string into a list
        list1=stringToList(e)
        # Removing all the stopwords in the list
        new_list=removeStopwords(list1)
        # Making a new list with all the unique values
        final_list= uniqueWordsInlist(new_list)
        # Converting list to string
        for ele in final_list:  
            str1 += ele
            str1 += ","


    
    elif a.endswith('.docx'):
        #calling readDocxfile function to read the text file as a list
        b=readDocxfile(a)
        #Converting the list to string
        c=listToString(b)
        # Calling function to remove URLs from string
        d=removeURLs(c)
        # Calling remove_punctution function to remove punctuations from the string
        e=remove_punctuation(d)
        # Converting all the words into lower case letters
        f=e.lower()
        # Converting the string into a list
        list1=stringToList(f)
        # Removing all the stopwords in the list
        new_list= removeStopwords(list1)
        # Making a new list with all the unique values
        final_list= uniqueWordsInlist(new_list)
        # Converting list to string
        for ele in final_list:  
            str1 += ele
            str1 += ","
    
    
    return str1

# %%
# Calling the fnction recursively for all the files extracted from zip file
for i in list_final:
    # Storing the reurned value after calling the functions file
    file=remove(i)

# %%
print(file)
# Out:
# "Week 10\52256-0.txt" : project,gutenberg,ebook,lead,pencil,manufactory,w,faber,stein,near,nürnberg,bavaria,use,anyone,anywhere,united,states,parts,world,cost,almost,restrictions,whatsoever,may,copy,give,away,reuse,terms,license,included,online,wwwgutenbergorg,located,youll,check,laws,country,using,title,author,release,date,june,7,2016,52256,language,english,character,set,encoding,utf8,start,produced,deaurider,carolyn,jablonski,distributed,proofreading,team,file,images,generously,made,available,internet,archive,historical,sketch,commemoration,jubilee,celebrated,year,1861,mark,completion,first,century,existence,establishment,dedicated,proprietor,patrons,business,friends,moss,co,agents,siberian,pencils,432,chestnut,street,philadelphia,descriptive,list,see,page,20,23,inclusive,especially,adapted,engineers,architects,artists,wood,engravers,office,extra,soft,black,marked,b,1,2,hard,h,3,middling,f,4,5,harder,cards,10,one,grades,boxes,knife,rubber,patent,moveable,leads,quality,containing,six,grade,dealers,drawing,instruments,papers,tracing,cloth,paper,c,illustration,j,l,geb,12,juni,1817,printed,u,e,sebald,everyone,knows,invention,modern,times,unhesitatingly,placed,side,numerous,improvements,inventions,means,last,three,centuries,particular,largely,contributed,towards,spread,arts,sciences,facilitation,study,communication,classic,ages,art,general,every,application,writing,material,entirely,unknown,middle,hear,employed,purpose,metal,however,sort,thing,indeed,mentioned,conjunction,account,bearing,resemblance,besides,used,ruling,lines,instance,purposes,leadruler,form,sharpedged,disc,said,even,later,periods,developement,growth,painting,traces,pencillike,drawings,begin,manifest,masters,fourteenth,van,eyck,fifteenth,memlink,others,appear,mention,works,executed,instrument,upon,chalked,generally,designated,silverstyle,specification,capable,closer,confirmation,though,much,certain,pure,silver,intended,implied,like,manner,reported,italian,latter,part,drew,smooth,deal,covered,dust,calcined,bones,process,appears,met,partial,success,hand,italy,done,styles,composed,mixture,tin,could,effaced,bread,crumb,petrarch,laura,delineated,contemporary,time,michael,angelo,still,introduced,germany,name,know,called,stile,never,seem,universally,acknowledged,period,pen,came,well,writingmaterial,added,flourishing,days,chalk,red,enjoyed,extensive,italians,obtained,best,spain,vasari,speaking,artist,sixteenth,remarks,understood,style,equal,dexterity,belongs,also,discovery,production,new,drawingmaterial,conferred,many,benefits,practical,life,england,reign,queen,elisabeth,1564,blacklead,mines,borrowdale,cumberland,discovered,opening,mine,element,present,render,trade,soil,possible,1565,manufactured,valuable,nature,produce,exposed,predatory,attacks,inhabitants,neighbouring,mountains,supply,day,leadpencils,manufacturing,simple,soon,cut,proper,size,saw,without,manipulation,fastened,remarkable,decidedly,unsurpassed,manufacture,softness,delicacy,although,great,request,really,meet,exigency,long,felt,excellent,given,lasting,universal,reputation,remained,open,weeks,yet,short,stated,value,40000,million,francs,raw,sent,london,sold,auction,market,sales,taking,place,monday,month,price,averaged,3640,shillings,per,pound,good,according,dufrénoy,400,kilogramme,fact,government,considered,expedient,rigorously,prohibit,export,goes,prove,importance,connexion,spite,might,exported,working,continued,upwards,began,effect,diminishing,yield,nothing,inferior,impure,longer,order,protect,consequences,failure,strenuously,sought,direction,deposits,desired,therefore,look,whereby,refuse,obtainable,purified,invented,consisted,grinding,powder,purifying,foreign,substances,chemical,finally,compressing,press,mass,easily,notwithstanding,appliances,science,brought,bear,subject,exertion,composition,perfect,hitherto,succeeded,producing,replacing,natural,circumstances,operated,inducement,search,substitute,would,admit,greater,economy,experiments,view,various,glue,isinglass,tragacanth,gum,tried,cementing,consolidating ...

# %%
# Opening a new file.dat in the curent directory and writing the file value into it 
with open("Week 10\\file.dat", "w",encoding="utf8") as text_file:
    text_file.write(file)
